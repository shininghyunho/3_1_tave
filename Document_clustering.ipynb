# %%
import numpy as np
import pandas as pd
import nltk
import re
import os
import codecs
from sklearn import feature_extraction
import mpld3

# %%
print titles[:10] #first 10 titles
# Out:
#   File "<ipython-input-5-1b950df9c6e0>", line 1
#     print titles[:10] #first 10 titles
#                ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(titles[:10] #first 10 titles)?
